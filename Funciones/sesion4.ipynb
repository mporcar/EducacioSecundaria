# %% [markdown]
# # Sesión 4: Funciones polinomiales y de raiz
# En esta sesión trabajaremos como se declaran funciones en python y como se realizan gráficas

# %% [markdown]
# ### Instrucciones Jupyter notebook
# * ctrl + enter = ejecutar celda
# * shift + enter = ejecutar celda y pasar a la siguiente
# * Esc + M = transformar celda en texto markdown
# * Esc + Y = transformar celda en código

# %% [markdown]
# ### Instrucciones básicas python
# \# la almuadilla se utiliza para comentar instrucciones => a partir de la almuadilla el código no se ejecuta
#
# Consejo: utilizad la almuadilla constantemente para anotar todos los pasos
#
# * Las instrucciones se ejecutan de arriba hacia abajo por orden
# * Operaciones básicas
#     * +: suma
#     * -: resta
#     * *: multiplicación
#     * /: división
#     * %: resto de una división. Ej: 7%3 es 1
#     * \** potencia. Ej: $3^2$ se escribe en python como 3**2
# * funciones básicas
#     * print("texto a imprimir", 4, "tantos elementos como querais separados por comas")
# * declarar una variable
#     * x = 4
#     * El nombre de la variable es x
#     * "Guardamos" el valor 4 en la variable x.
#     * Podemos utilizar esta variable después de guardarla
# * Tipos de objetos (objeto es el valor que se puede guardar en una variable)
#     * Numericos: 3, 2.4, -0.0003
#     * Texto (Entre comillas): "hola clase"
#     * booleanos: variables con dos valores True o False (lo veremos más adelante)
#     * Otros

# %% [markdown]
# ### Funciones en python
# Una función en python es un objeto que se puede utilizar posteriormente
# * Dentro de los parentesis estaran los argumentos de la función, es decir, que es lo que recive la función como input
# * la función puede tener o no la clausula return, que indica que es lo que la función nos retorna

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Para declarar una función es necesario la clausula def
def f(x): # la función recive 2 argumentos
    return x**2+2*x+5
    
# para utilizar la funcion
print(f(5))

# si hay un return, la función retorna un objeto (un valor)
x = f(5)
print("El resultado de mi función es", x)
# Out:
# 40
# El resultado de mi función es 40

# %%
def mi_funcion(z): # la función recive 1 argumento, pero m no existe fuera de la función
    return z**2

x = np.arange(-10,10)
fx = mi_funcion(x)

# %%
v = np.arange(-1000,1000)
cuadrado = v**2

plt.title('Titulo') # titulo
plt.ylim((0,100)) # con ylim podemos definir el rango del eje vertical
plt.xlim((-5,10))# con xlim podemos definir el rango del eje horizontal

plt.plot(v, cuadrado, color = "r") # podemos poner diferentes lineas en un mismo grafico
plt.plot(v, v, color = "g") # con diferente color

# podemos poner el nombre de los ejes
plt.xlabel("X")
plt.ylabel("f(x)")
plt.show() # con esto mostramos el grafico sin el Out

# %% [markdown]
# ### Ejercicio 1: Funciones polinomiales
# a) Los beneficios de una ventas de un producto en una empresa vienen dados por la formula: $Beneficios = -2n^2+1000n+20000$. Programad la función y graficadla. ¿En que punto se encuentra el máximo beneficio? ¿Tiene sentido graficar la función en los puntos negativos?

# %%
def beneficios(n): # la función recive 1 argumento, pero m no existe fuera de la función
    return -2*n**2+1000*n+2000

x = np.arange(0,1000)
fx = beneficios(x)
plt.plot(x,fx)
plt.show()

# %% [markdown]
# b) La suma de los numeros enteros desde $1$ hasta $n$ es $n(n+1)/2$. Programad la función y graficadla. Elegid correctamente los ejes.

# %% [markdown]
# c) El area de un circulo viene dado por $\pi r^2$, donde r es el radio. Programad la función que da el área de un circulo en función de su radio. Utilizad la constante np.pi de numpy y graficad la función.

# %% [markdown]
# d) Programad la función $f(x) = x^n$, donde $n$ es un entero positivo. Graficad la función varias veces y explicad para cada caso si es creciente, decreciente (o ninguno de los dos casos) o si es simétrica o no lo es.

# %% [markdown]
# ### Ejercicio 2: Funciones de raiz
# Ejercicios entregables a y b.
#
# a) Programa las funciones siguientes:
#    * $f(x) = \sqrt{x}-b$
#    * $h(x) = \sqrt{x-b}$

# %% [markdown]
# b) Grafícalas y explica las diferencias. Formaliza donde estan los puntos de corte con los ejes.

# %% [markdown]
# c) Programa las funciones siguientes:
#    * $f(x) = \sqrt{bx}$
#    * $h(x) = b\sqrt{x}$

# %% [markdown]
# d) Grafícalas y explica las diferencias.

# %% [markdown]
# e) Programa la función $f(x)=\sqrt[n]{x}$. Graficala para diferentes $n$ y explica las diiferencias.

# %%
def f(x, n):

# %% [markdown]
# ### Ejercicio 3: Análisis de funciones polinomiales y de raiz
# Sea la función $f(x)=ax^2+bx+c$.
#
# Ejercicios entregables a, b y c.
#
# a) Programad una función que tenga como entrada los argumentos x, a, b, c y que retorne el $f(x)$

# %%
def f(x,a,b,c): # la función recive 1 argumento, pero m no existe fuera de la función
    return a*x**2+b*x+c

# %% [markdown]
# b) Crea un vector x de -100 a 100. Probad la función fijando 2 de los 3 parametros a, b y c y variando uno.

# %%
x = np.arange(-1000,1000)
fx = f(x,1,1,1)
plt.plot(x,fx)

# %% [markdown]
# c) Que sucede cuando variamos cada uno de los parametros?

# %% [markdown]
# Sea la función $f(x)=\sqrt[3]{x}$.
#
# d) Programad la función y calculad el resultado para -1. ¿Que aparece?

# %%
def f(x):
    return x**(1/3)

# %% [markdown]
# Lo que aparece es un numero complejo, tal como hemos visto en anteriores unidades didácticas. Python tiene la capacidad para calcularlos

# %%
a=f(-2)

print(a)
# podemos obtener la parte real del numero
print(a.real)
# asi como la parte imaginaria
print(a.imag)
# Out:
# (0.6299605249474367+1.0911236359717214j)
# 0.6299605249474367
# 1.0911236359717214
