# %% [markdown]
# # Sesión 7 Funciones logarítmicas y exponenciales

# %% [markdown]
# ### Instrucciones Jupyter notebook
# * ctrl + enter = ejecutar celda
# * shift + enter = ejecutar celda y pasar a la siguiente
# * Esc + M = transformar celda en texto markdown
# * Esc + Y = transformar celda en código

# %% [markdown]
# ### Instrucciones básicas python
# \# la almuadilla se utiliza para comentar instrucciones => a partir de la almuadilla el código no se ejecuta
#
# Consejo: utilizad la almuadilla constantemente para anotar todos los pasos
#
# * Las instrucciones se ejecutan de arriba hacia abajo por orden
# * Operaciones básicas
#     * +: suma
#     * -: resta
#     * *: multiplicación
#     * /: división
#     * %: resto de una división. Ej: 7%3 es 1
#     * \** potencia. Ej: $3^2$ se escribe en python como 3**2
# * funciones básicas
#     * print("texto a imprimir", 4, "tantos elementos como querais separados por comas")
# * declarar una variable
#     * x = 4
#     * El nombre de la variable es x
#     * "Guardamos" el valor 4 en la variable x.
#     * Podemos utilizar esta variable después de guardarla
# * Tipos de objetos (objeto es el valor que se puede guardar en una variable)
#     * Numericos: 3, 2.4, -0.0003
#     * Texto (Entre comillas): "hola clase"
#     * booleanos: variables con dos valores True o False (lo veremos más adelante)
#     * Otros

# %% [markdown]
# ### Funciones en python
# Una función en python es un objeto que se puede utilizar posteriormente
# * Dentro de los parentesis estaran los argumentos de la función, es decir, que es lo que recive la función como input
# * la función puede tener o no la clausula return, que indica que es lo que la función nos retorna

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Para declarar una función es necesario la clausula def
def f(x): # la función recive 2 argumentos
    return np.exp(x)
    
def h(x): # la función recive 2 argumentos
    return np.log(x)

x = np.arange(-50000,50000)/10
fx = f(x)

plt.title('Titulo') # titulo
plt.ylim((-10,10)) # con ylim podemos definir el rango del eje vertical
plt.xlim((-5,5))# con xlim podemos definir el rango del eje horizontal

# ejes verticales y horizontales
plt.axhline(0, color='black')
plt.axvline(0, color='black')

plt.plot(x, fx, color = "r") # podemos poner diferentes lineas en un mismo grafico
plt.plot(x, h(x), color = "g") # con diferente color



# podemos poner el nombre de los ejes
plt.xlabel("X")
plt.ylabel("f(x)")
plt.show() # con esto mostramos el grafico sin el Out
# Out:
# <ipython-input-5-c5b8364498c0>:3: RuntimeWarning: overflow encountered in exp
#   return np.exp(x)
# <ipython-input-5-c5b8364498c0>:6: RuntimeWarning: divide by zero encountered in log
#   return np.log(x)
# <ipython-input-5-c5b8364498c0>:6: RuntimeWarning: invalid value encountered in log
#   return np.log(x)

# %% [markdown]
# ### Ejercicio 1 : Funciones exponenciales
# Ejercicio entregable a)
#
# Programa la función $f(x)=Ae^{Bx}$. ¿Cómo afectan los parametros A y B a las características de la función?

# %% [markdown]
# ### Ejercicio 2: Funciones logarítmicas
# a) Programa la función $f(x)=Alog(Bx-C)$. ¿Cómo afectan los parametros A y B a las características de la función?

# %% [markdown]
# ### Ejercicio 3: Problemas funciones exponenciales y logarítmicas
# Ejercicios entregables a, b y c
#
# a) La población $N$ de una sociedad particular está dada por una función exponencial del tipo $N=N_{0}e^{k\cdot t}$ donde $x$ son los años. Se ha observado que la población ha crecido un 30% en 3 años. Obten los parametros de la función función, programala y graficala.

# %%
# Nota: la constante e está definida en python
np.e
# Out:
# 2.718281828459045

# %% [markdown]
# b) ¿En cuantos años se habrá crecido un 80%?

# %% [markdown]
# c) Aislad $t$ en la ecuación anterior y tendremos la función del tiempo en función de la población. Programa esta función y graficala.
